# %%
#basic image processing

# %%
# %pip install opencv-python
import cv2
# Out:
# Requirement already satisfied: opencv-python in c:\users\lapto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in c:\users\lapto\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from opencv-python) (2.2.3)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 26.0.1
# [notice] To update, run: C:\Users\lapto\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
img=cv2.imread("image.jpg")
img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
img_comp=255-img

# %%
cv2.imshow("image", img)
cv2.imshow("gray image", img_gray)
cv2.imshow("complement image", img_comp)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
cv2.imwrite("image_1.jpg",img)
cv2.imwrite("image_gray.jpg",img_gray)
cv2.imwrite("image_comp.jpg",img_comp)
# Out:
# True
